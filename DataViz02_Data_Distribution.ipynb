# %% [markdown]
# <a href="https://colab.research.google.com/github/suwitchaya17/data_viz_2022/blob/main/DataViz02_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd #นำเข้าฟังชันก์ pandas โยกำหนดให้ชื่อ pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv') 
# กำหนด  df ให้เก็บค่าข้อมูลที่ใช้อ่านCSVข้อดีของการใช้read_csvคือสามารถนำเข้าข้อมูลจากเว็บไซต์ได้
df #แสดงค่าในตารางซึ่งเป็นข้อมูลของดอกไอริส
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# SepalLength (ความยาวกลีบเลี้ยง)
#
# SepalWidth (ความกว้างกลีบเลี้ยง)
#
# PetalLength (ความยาวกลีบดอก)
#
# PetalWidth (ความกว้างกลีบดอก)

# %% [markdown]
# # Scatter Plot

# %%
from matplotlib import pyplot as plt 
# matplotlib เป็น Library ใหญ่ สำหรับวาดกราฟ โดยเลือกใช้เฉพาะ library ที่ชื่อ pyplot

# %%
plt.scatter([1,-1],[2,-1])

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %% [markdown]
# ## เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# ## ระบุสีให้แต่ละจุด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ## แทนค่าตัวอักษรด้วยสี r g b c y k w

# %%
df2 = df.replace({'Iris-setosa':'r', 'Iris-versicolor':'g','Iris-virginica':'b'})

# %%
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])

# %% [markdown]
# ## เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อ marker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ### ใช้ขนาดของ marker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica',s=df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# #### ขยายขนาดของ marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ### ปรับความโปรงใสของ marker เพื่อให้มองเห็นจุดที่ถูกบัง (Bubble Chart)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='virginica',s=40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ### เปลี่ยน หน้าตาของ Marker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='X')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='X')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='X')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='$s$')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='$c$')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='$g$')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s=80*df2['PetalWidth'])

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa')
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor')
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength']) 
#ดูการกระจายของ SepalLength โดยไม่สนว่าแนวกลีบดอกหรือกลีบเลี้ยงเป็นอย่างไร ดูพวกค่า maximum minimum ข้อมูลเป็น normal
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f07430f5c90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f07430fec50>,
#   <matplotlib.lines.Line2D at 0x7f07431051d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0743105c90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0743105750>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f07430fe1d0>,
#   <matplotlib.lines.Line2D at 0x7f07430fe710>]}

# %%
plt.boxplot(df['SepalLength'],vert=False) #กำหนด vert = False เพื่อเป็นแนวนอน
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f07430e6590>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f07430eb590>,
#   <matplotlib.lines.Line2D at 0x7f07430ebad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f07430735d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0743073090>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f07430e6ad0>,
#   <matplotlib.lines.Line2D at 0x7f07430eb050>]}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False) #ดึงค่ามาใช้ ybp =y boxplot ตัวหนังสือหายไปเพราะมีไรมารับ

# %% [markdown]
# ## median

# %%
ybp['medians'][0].get_ydata()    #บอกว่าเส้นนี้ถูกวาดยังไง ในแกน Y
# Out:
# array([0.925, 1.075])

# %%
ybp['medians'][0].get_xdata()
# Out:
# array([5.8, 5.8])

# %%
ybp['whiskers'][0].get_xdata()
# Out:
# array([5.1, 4.3])

# %% [markdown]
# ## min

# %%
min(ybp['whiskers'][0].get_xdata())
# Out:
# 4.3

# %% [markdown]
# ## max

# %%
max(ybp['whiskers'][1].get_xdata())
# Out:
# 7.9

# %%
ybp['caps'][1].get_xdata()
# Out:
# array([7.9, 7.9])

# %% [markdown]
# ## q1

# %%
ybp['boxes'][0].get_xdata()
# Out:
# array([5.1, 5.1, 6.4, 6.4, 5.1])

# %%
ybp['boxes'][0].get_xdata()[0]
# Out:
# 5.1

# %%
max(ybp['whiskers'][0].get_xdata())
# Out:
# 5.1

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f0746b1e2d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0746be1f50>,
#   <matplotlib.lines.Line2D at 0x7f0746be1e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0746bb9e50>],
#  'means': [<matplotlib.lines.Line2D at 0x7f0746b01f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0746aaaf50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f0746b1eb90>,
#   <matplotlib.lines.Line2D at 0x7f0746be1390>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline=True,showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f0746ca4150>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0746cb4590>,
#   <matplotlib.lines.Line2D at 0x7f0746cb4550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0746ce3b90>],
#  'means': [<matplotlib.lines.Line2D at 0x7f0746c7cbd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0746c7cd50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f0746ca4210>,
#   <matplotlib.lines.Line2D at 0x7f0746cb4990>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'o'})
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f0746cc39d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f0746da7150>,
#   <matplotlib.lines.Line2D at 0x7f0746da7790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0746d97cd0>],
#  'means': [<matplotlib.lines.Line2D at 0x7f0746d97ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0746d97490>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f0746cc3810>,
#   <matplotlib.lines.Line2D at 0x7f0746da7650>]}

# %%
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3
#def box_vals(ybp,vert=True) :
#   if vert == True :   
#        q1 = ybp['boxes'][0].get_ydata()[0]
#        q2 = ybp['medians'][0].get_ydata()[0]
#       q3 = ybp['boxes'][0].get_ydata()[2]
#       mmin = min(ybp['caps'][0].get_ydata())
#       mmax = max(ybp['caps'][1].get_ydata())
#   else :
#       q1 = ybp['boxes'][0].get_xdata()[0]
#       q2 = ybp['medians'][0].get_xdata()[0]
#       q3 = ybp['boxes'][0].get_xdata()[2]
#       mmin = min(ybp['caps'][0].get_xdata())
#       mmax = max(ybp['caps'][1].get_xdata())
#   return  q1,q2,q3,mmin,mmax

# %% [markdown]
# # Quiz กลุ่มfinal
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3
# 2. วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %% [markdown]
# ## 1.เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3

# %%
from matplotlib import pyplot as plt 
# matplotlib เป็น Library ใหญ่ สำหรับวาดกราฟ โดยเลือกใช้เฉพาะ library ที่ชื่อ pyplot

# %%
def box_vals(ybp,vert=True): #ใช้คำสั่ง vert = True  เพื่อให้ boxplot เป็นแนวนอน #บอกว่าเส้นนี้ถูกวาดยังไง ในแกน Y
    q1=ybp['boxes'][0].get_xdata()[0] 
    q2=ybp['medians'][0].get_xdata()[0]
    q3=ybp['boxes'][0].get_xdata()[2]
    mmin=min(ybp['caps'][0].get_xdata())
    mmax=max(ybp['caps'][1].get_xdata())
    print(f'q1={q1}\nq2={q2}\nq3={q3}\nmin={mmin}\nmax={mmax}\n');

# %%
box_vals(ybp,vert=True)
# Out:
# q1=5.1
# q2=5.8
# q3=6.4
# min=4.3
# max=7.9

# %% [markdown]
# ## 2.วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
import seaborn as sns

# %%
# กำหนดขนาดของกราฟ
fig, ax = plt.subplots(figsize=(12, 7)) #กว้าง 12 ยาว 7

ax.grid(color='grey', axis='y', linestyle='-', linewidth=0.25, alpha=0.5)

# ในกรณีที่เราอยากดูการกระจายของข้อมูลในแต่ละ Feature แต่อยากให้แบ่งแยกตามชนิดของ species(Class) ด้วย
# แอลฟา : กำหนดความโปร่งใส ค่าน้อยโปร่งใสมาก ค่ามากยิ่งทึบแสง ; df : ดีฟอล
sns.boxplot(x='Name', y='PetalLength', data=df)

# ตั้งชื่อ boxplot
plt.title('Distribution of petal length by species');

# %% [markdown]
# ### เฉลย Quiz กลุ่ม final

# %%
bb = plt.boxplot(df['SepalLength'])

# %%
def detail_boxreturn(boxreturn):
    q1 = boxreturn['boxes'][0].get_ydata()[0]
    q2 = boxreturn['medians'][0].get_ydata()[0]
    q3 = boxreturn['boxes'][0].get_ydata()[2]
    minv = min(boxreturn['whiskers'][0].get_ydata())
    maxv = max(boxreturn['whiskers'][1].get_ydata())
    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn(bb)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
bb2 = plt.boxplot(df['SepalLength'],vert=False)

# %%
detail_boxreturn(bb2)
# Out:
# min = 1.0, max = 1.0, q1 = 0.925, q2 = 0.925, q3 = 1.075

# %%
def detail_boxreturn_v2(boxreturn, vert=True):
    if vert == True:
        q1 = boxreturn['boxes'][0].get_ydata()[0]
        q2 = boxreturn['medians'][0].get_ydata()[0]
        q3 = boxreturn['boxes'][0].get_ydata()[2]
        minv = min(boxreturn['whiskers'][0].get_ydata())
        maxv = max(boxreturn['whiskers'][1].get_ydata())     
    else: #vert == False
        q1 = boxreturn['boxes'][0].get_xdata()[0]
        q2 = boxreturn['medians'][0].get_xdata()[0]
        q3 = boxreturn['boxes'][0].get_xdata()[2]
        minv = min(boxreturn['whiskers'][0].get_xdata())
        maxv = max(boxreturn['whiskers'][1].get_xdata())   

    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn_v2(bb)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
detail_boxreturn_v2(bb2,vert=False)
# Out:
# min = 4.3, max = 7.9, q1 = 5.1, q2 = 5.8, q3 = 6.4

# %%
plt.boxplot(df['PetalLength'][:50],positions = [1] )
plt.boxplot(df['PetalLength'][50:100],positions = [2] )
plt.boxplot(df['PetalLength'][100:150],positions = [3] );

# %% [markdown]
# # Violin plot

# %%
bb = plt.boxplot(df['PetalLength'][:50])

# %%
plt.violinplot(df['PetalLength'][:50])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f073212c350>],
#  'cbars': <matplotlib.collections.LineCollection at 0x7f073212c510>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f07321d1510>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f073212c490>}

# %%
plt.subplot(1,2,1)
bb = plt.boxplot(df['PetalLength'][:50])
q1 = bb['boxes'][0].get_ydata()[0]
q2 = bb['medians'][0].get_ydata()[0]
q3 = bb['boxes'][0].get_ydata()[2]
plt.subplot(1,2,2)
vi = plt.violinplot(df['PetalLength'][:50],showmedians=True)

# %% [markdown]
# # HW ทดลอง plot ค่า quantile ลงไปในกราฟ (ศึกษาตัวแปล quantiles)
