# %% [markdown]
# <a href="https://colab.research.google.com/github/suwitchaya17/data_viz_2022/blob/main/project_dashboad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #เตรียมข้อมูล

# %%
import pandas as pd  #ทำงานกับข้อมูลลักษณะตาราง
import os  #จัดการไฟล์และ path

# %%
from google.colab import drive  #เชื่อม google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/covid_data'   #pathจะชี้ไปยังโฟล์เดอร์
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Data Covid
# ต้องการข้อมูลของวันที่ 1 มกราคม 2021 - 11 มีนาคม 2022

# %% [markdown]
# ## 2021-10-26 ถึง 2022-02-27

# %%
data1 =  os.path.join(path,'confirmed-cases-since-271064.xlsx') #แล้วก็ชี้ไปที(data1)
print(data1)
# Out:
# /content/drive/My Drive/covid_data/confirmed-cases-since-271064.xlsx

# %%
data2 = pd.read_excel(data1)  #กำหนดตัวแปร data1_1 เป็นข้อมูลของผู้ป่วยโควิด
data2 #เรียกดูตารางของผู้ป่วยโควิด
# Out:
#              No. announce_date Notified date   sex  age Unit nationality  \
# 0        1859158    2021-10-26    2021-10-25   ชาย   20   ปี    Thailand
# 1        1859159    2021-10-26    2021-10-25  หญิง   42   ปี    Thailand
# 2        1859160    2021-10-26    2021-10-25  หญิง   33   ปี    Thailand
# 3        1859161    2021-10-26    2021-10-25  หญิง   52   ปี    Thailand
# 4        1859162    2021-10-26    2021-10-25  หญิง   84   ปี    Thailand
# ...          ...           ...           ...   ...  ...  ...         ...
# 1010454  2869612    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010455  2869613    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010456  2869614    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010457  2869615    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010458  2869616    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# ...

# %%
data2[data2['announce_date']=='2022-01-01'] #เพื่อดูว่าข้อมูลที่เราต้องการเริ่มที่ low ที่เท่าไหร่
# Out:
#             No. announce_date Notified date   sex  age Unit nationality  \
# 364278  2223436    2022-01-01    2021-12-31   ชาย   39   ปี    Thailand
# 364279  2223437    2022-01-01    2021-12-31  หญิง   39   ปี    Thailand
# 364280  2223438    2022-01-01    2021-12-31   ชาย   64   ปี    Thailand
# 364281  2223439    2022-01-01    2021-12-31   ชาย   27   ปี    Thailand
# 364282  2223440    2022-01-01    2021-12-31  หญิง   35   ปี    Thailand
# ...         ...           ...           ...   ...  ...  ...         ...
# 367284  2226442    2022-01-01    2021-12-31   ชาย  NaN  NaN         NaN
# 367285  2226443    2022-01-01    2021-12-31   ชาย  NaN  NaN         NaN
# 367286  2226444    2022-01-01    2021-12-31   ชาย  NaN  NaN         NaN
# 367287  2226445    2022-01-01    2021-12-31   ชาย  NaN  NaN         NaN
# 367288  2226446    2022-01-01    2021-12-31  หญิง  NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %%
data3 = data2.iloc[364278:1010458,:] #เรียกดูตารางใหม่ที่ตัดออกมา จะได้วันที่ 2022-01-01 ถึง 2022-02-27
data3
# Out:
#              No. announce_date Notified date   sex  age Unit nationality  \
# 364278   2223436    2022-01-01    2021-12-31   ชาย   39   ปี    Thailand
# 364279   2223437    2022-01-01    2021-12-31  หญิง   39   ปี    Thailand
# 364280   2223438    2022-01-01    2021-12-31   ชาย   64   ปี    Thailand
# 364281   2223439    2022-01-01    2021-12-31   ชาย   27   ปี    Thailand
# 364282   2223440    2022-01-01    2021-12-31  หญิง   35   ปี    Thailand
# ...          ...           ...           ...   ...  ...  ...         ...
# 1010453  2869611    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010454  2869612    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010455  2869613    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010456  2869614    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010457  2869615    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## 2022-02-28 ถึง 2022-03-23

# %%
data4 = os.path.join(path,'confirmed-cases-since-280265.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(data4) #เรียกดูตารางของผู้ป่วยโควิด
# Out:
# /content/drive/My Drive/covid_data/confirmed-cases-since-280265.xlsx

# %%
data5 = pd.read_excel(data4)  #กำหนดตัวแปร data_covid เป็นข้อมูลของผู้ป่วยโควิด
data5  #เรียกดูตารางของผู้ป่วยโควิด
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617    2022-02-28    2022-02-27   ชาย  41.0   ปี    Thailand
# 1       2869618    2022-02-28    2022-02-27  หญิง  45.0   ปี    Thailand
# 2       2869619    2022-02-28    2022-02-27  หญิง  40.0   ปี    Thailand
# 3       2869620    2022-02-28    2022-02-27   ชาย  44.0   ปี    Thailand
# 4       2869621    2022-02-28    2022-02-27   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 554335  3423952    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554336  3423953    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554337  3423954    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554338  3423955    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554339  3423956    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %%
data5[data5['announce_date']=='2022-03-11'] #เพื่อดูว่าข้อมูลที่เราต้องการควรตัดที่ low ที่เท่าไหร่
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 242241  3111858    2022-03-11    2022-03-10  หญิง  29.0   ปี         NaN
# 242242  3111859    2022-03-11    2022-03-10  หญิง  18.0   ปี         NaN
# 242243  3111860    2022-03-11    2022-03-10  หญิง  28.0   ปี         NaN
# 242244  3111861    2022-03-11    2022-03-10  หญิง  51.0   ปี         NaN
# 242245  3111862    2022-03-11    2022-03-10  หญิง  43.0   ปี         NaN
# ...         ...           ...           ...   ...   ...  ...         ...
# 267028  3136645    2022-03-11    2022-03-10   ชาย   NaN  NaN         NaN
# 267029  3136646    2022-03-11    2022-03-10  หญิง   NaN  NaN         NaN
# 267030  3136647    2022-03-11    2022-03-10  หญิง   NaN  NaN         NaN
# 267031  3136648    2022-03-11    2022-03-10   NaN   NaN  NaN         NaN
# 267032  3136649    2022-03-11    2022-03-10   ชาย   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %%
data6 = data5.iloc[0:267032,:] #เรียกดูตารางใหม่ที่ตัดออกมา จะได้วันที่ 2022-02-28 ถึง 2022-03-11
data6
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617    2022-02-28    2022-02-27   ชาย  41.0   ปี    Thailand
# 1       2869618    2022-02-28    2022-02-27  หญิง  45.0   ปี    Thailand
# 2       2869619    2022-02-28    2022-02-27  หญิง  40.0   ปี    Thailand
# 3       2869620    2022-02-28    2022-02-27   ชาย  44.0   ปี    Thailand
# 4       2869621    2022-02-28    2022-02-27   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 267027  3136644    2022-03-11    2022-03-10   ชาย   NaN  NaN         NaN
# 267028  3136645    2022-03-11    2022-03-10   ชาย   NaN  NaN         NaN
# 267029  3136646    2022-03-11    2022-03-10  หญิง   NaN  NaN         NaN
# 267030  3136647    2022-03-11    2022-03-10  หญิง   NaN  NaN         NaN
# 267031  3136648    2022-03-11    2022-03-10   NaN   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ### ต่อตาราง data3 และ data6
#
#
# เพื่อที่จะได้วันที่ ต้องการข้อมูลของวันที่ 1 มกราคม 20212 - 11 มีนาคม 2022

# %%
covid = pd.concat([data3,data6])
covid
# Out:
#             No. announce_date Notified date   sex  age Unit nationality  \
# 364278  2223436    2022-01-01    2021-12-31   ชาย   39   ปี    Thailand
# 364279  2223437    2022-01-01    2021-12-31  หญิง   39   ปี    Thailand
# 364280  2223438    2022-01-01    2021-12-31   ชาย   64   ปี    Thailand
# 364281  2223439    2022-01-01    2021-12-31   ชาย   27   ปี    Thailand
# 364282  2223440    2022-01-01    2021-12-31  หญิง   35   ปี    Thailand
# ...         ...           ...           ...   ...  ...  ...         ...
# 267027  3136644    2022-03-11    2022-03-10   ชาย  NaN  NaN         NaN
# 267028  3136645    2022-03-11    2022-03-10   ชาย  NaN  NaN         NaN
# 267029  3136646    2022-03-11    2022-03-10  หญิง  NaN  NaN         NaN
# 267030  3136647    2022-03-11    2022-03-10  หญิง  NaN  NaN         NaN
# 267031  3136648    2022-03-11    2022-03-10   NaN  NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# #### ตัดเอาเฉพาะคอลัมน์ที่ต้องการ

# %%
data_covid = covid[['No.','announce_date','sex','age','risk','province_of_onset']]
data_covid
# Out:
#             No. announce_date   sex  age  \
# 364278  2223436    2022-01-01   ชาย   39
# 364279  2223437    2022-01-01  หญิง   39
# 364280  2223438    2022-01-01   ชาย   64
# 364281  2223439    2022-01-01   ชาย   27
# 364282  2223440    2022-01-01  หญิง   35
# ...         ...           ...   ...  ...
# 267027  3136644    2022-03-11   ชาย  NaN
# 267028  3136645    2022-03-11   ชาย  NaN
# 267029  3136646    2022-03-11  หญิง  NaN
# 267030  3136647    2022-03-11  หญิง  NaN
# 267031  3136648    2022-03-11   NaN  NaN
#
#                                                risk province_of_onset
# 364278                                        อื่นๆ             พะเยา
# 364279  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 364280  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 364281  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 364282                         อยู่ระหว่างการสอบสวน             พะเยา
# ...

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
data_covid.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง data_covid
#เนื่องจากมี True แสดงว่ามีค่าที่เป็น Missing จะทำการลบค่า Missing ต่อไป
# Out:
# No.                  False
# announce_date        False
# sex                   True
# age                   True
# risk                  True
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ####แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data_covid

# %%
covid_updated = data_covid.fillna(value={'No.':'ไม่ทราบ','announce_date':'ไม่ทราบ','sex':'ไม่ทราบ','age':'ไม่ทราบ','risk':'ไม่ทราบ','province_of_onset':'ไม่ทราบ'}) #แทน missing ด้วยค่าที่เหมาะสม จากตาราง data_covid
covid_updated # แสดงตาราง covid_updated
# Out:
#             No. announce_date      sex      age  \
# 364278  2223436    2022-01-01      ชาย       39
# 364279  2223437    2022-01-01     หญิง       39
# 364280  2223438    2022-01-01      ชาย       64
# 364281  2223439    2022-01-01      ชาย       27
# 364282  2223440    2022-01-01     หญิง       35
# ...         ...           ...      ...      ...
# 267027  3136644    2022-03-11      ชาย  ไม่ทราบ
# 267028  3136645    2022-03-11      ชาย  ไม่ทราบ
# 267029  3136646    2022-03-11     หญิง  ไม่ทราบ
# 267030  3136647    2022-03-11     หญิง  ไม่ทราบ
# 267031  3136648    2022-03-11  ไม่ทราบ  ไม่ทราบ
#
#                                                risk province_of_onset
# 364278                                        อื่นๆ             พะเยา
# 364279  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 364280  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 364281  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...

# %% [markdown]
# ####ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
covid_updated.isnull().any() #ดูค่า Missing คอลัมน์ของตาราง covid_updated หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                  False
# announce_date        False
# sex                  False
# age                  False
# risk                 False
# province_of_onset    False
# dtype: bool

# %% [markdown]
# ## **Data region

# %%
data7 = { 'จังหวัด':['อำนาจเจริญ','บึงกาฬ','บุรีรัมย์','ชัยภูมิ','กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม','มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู','หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ','สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร'
              ,'เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี'
              ,'ปทุมธานี', 'สมุทรปราการ', 'สมุทรสาคร', 'สมุทรสงคราม', 'สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา'
              ,'กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],    #column 1 -> จังหวัด
              '6 ภูมิภาค (ภูมิศาสตร์)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก'
              ,'กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],   #column 2 -> 6 ภูมิภาค (ภูมิศาสตร์)
              '4 ภูมิภาค (การเมือง)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],   #column 3 -> 4 ภูมิภาค (การเมือง)
              '6 ภูมิภาค (อุตุนิยมวิทยา)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย'
              ,'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'
              ,'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'],     #column 4 -> 6 ภูมิภาค (อุตุนิยมวิทยา)	
              '5 ภูมิภาค (การท่องเที่ยว)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']     #column 5 -> 5 ภูมิภาค (การท่องเที่ยว)
}

# %% [markdown]
# ### ตาราง data8 : ข้อมูลภูมิภาคของประเทศไทย

# %%
data8 = pd.DataFrame.from_dict(data7)   #กำหนดตัวแปร data8 เป็นข้อมูลภูมิภาคของประเทศไทย
data8   #เรียกดูตารางภูมิภาคของประเทศไทย
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# ..         ...                    ...                  ...
# 72       พังงา                    ใต้                  ใต้
# 73      ภูเก็ต                    ใต้                  ใต้
# 74       ระนอง                    ใต้                  ใต้
# 75        สตูล                    ใต้                  ใต้
# 76        ตรัง                    ใต้                  ใต้
#
#          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)
# 0               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 1               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# ...

# %% [markdown]
# #### ตัดเอาเฉพาะคอลัมน์ที่ต้องการ

# %%
region_updated = data8[['จังหวัด','6 ภูมิภาค (ภูมิศาสตร์)']]
region_updated
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# # ต่อตาราง data covid และ data region

# %%
covid_region = covid_updated.merge(region_updated,how='left',left_on = 'province_of_onset',right_on = 'จังหวัด') #เชื่อมตาราง 2 ตาราง คือ covid_updated และ region_updated
covid_region  #แสดงตาราง
# Out:
#             No. announce_date      sex      age  \
# 0       2223436    2022-01-01      ชาย       39
# 1       2223437    2022-01-01     หญิง       39
# 2       2223438    2022-01-01      ชาย       64
# 3       2223439    2022-01-01      ชาย       27
# 4       2223440    2022-01-01     หญิง       35
# ...         ...           ...      ...      ...
# 913207  3136644    2022-03-11      ชาย  ไม่ทราบ
# 913208  3136645    2022-03-11      ชาย  ไม่ทราบ
# 913209  3136646    2022-03-11     หญิง  ไม่ทราบ
# 913210  3136647    2022-03-11     หญิง  ไม่ทราบ
# 913211  3136648    2022-03-11  ไม่ทราบ  ไม่ทราบ
#
#                                                risk province_of_onset จังหวัด  \
# 0                                             อื่นๆ             พะเยา   พะเยา
# 1       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา   พะเยา
# 2       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา   พะเยา
# ...

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
covid_region.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง covid_region
#เนื่องจากมี True แสดงว่ามีค่าที่เป็น Missing จะทำการลบค่า Missing ต่อไป
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# risk                      False
# province_of_onset         False
# จังหวัด                    True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %% [markdown]
# ####แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data_covid

# %%
covid_region_updated = covid_region.fillna(value={'จังหวัด':'ไม่ทราบ','6 ภูมิภาค (ภูมิศาสตร์)':'ไม่ทราบ'}) #แทน missing ด้วยค่าที่เหมาะสม จากตาราง covid_region
covid_region_updated # แสดงตาราง covid_region_updated
# Out:
#             No. announce_date      sex      age  \
# 0       2223436    2022-01-01      ชาย       39
# 1       2223437    2022-01-01     หญิง       39
# 2       2223438    2022-01-01      ชาย       64
# 3       2223439    2022-01-01      ชาย       27
# 4       2223440    2022-01-01     หญิง       35
# ...         ...           ...      ...      ...
# 913207  3136644    2022-03-11      ชาย  ไม่ทราบ
# 913208  3136645    2022-03-11      ชาย  ไม่ทราบ
# 913209  3136646    2022-03-11     หญิง  ไม่ทราบ
# 913210  3136647    2022-03-11     หญิง  ไม่ทราบ
# 913211  3136648    2022-03-11  ไม่ทราบ  ไม่ทราบ
#
#                                                risk province_of_onset  \
# 0                                             อื่นๆ             พะเยา
# 1       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 3       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...

# %% [markdown]
# ####ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
covid_region_updated.isnull().any() #ดูค่า Missing คอลัมน์ของตาราง covid_region_updated หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# risk                      False
# province_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# dtype: bool

# %% [markdown]
# #### ตัดข้อมูลที่ไม่ทราบจังหวัดออก

# %% [markdown]
# ## **Data รายชื่อหน่วยงานที่เข้าร่วมโครงการหมอพร้อม

# %%
import pandas as pd  #ทำงานกับข้อมูลลักษณะตาราง
import os  #จัดการไฟล์และ path

# %%
from google.colab import drive  #เชื่อม google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/mohpromt_data'   #pathจะชี้ไปยังโฟล์เดอร์
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data9 = os.path.join(path,'MOHPROMT.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(data9)
# Out:
# /content/drive/My Drive/mohpromt_data/MOHPROMT.xlsx

# %% [markdown]
# ### ตาราง data10 : ข้อมูลรายชื่อหน่วยงานที่เข้าร่วมโครงการหมอพร้อม

# %%
data10 = pd.read_excel(data9)  #กำหนดตัวแปร data10  เป็นข้อมูลของรายชื่อหน่วยงานที่เข้าร่วมโครงการหมอพร้อม
data10  #เรียกดูตารางของรายชื่อหน่วยงานที่เข้าร่วมโครงการหมอพร้อม
# Out:
#                                              ชื่อ                     สาขา  \
# 0                                     ร้านยาฟารุก                     แว้ง
# 1                     อัสลามการแพทย์คลินิกเวชกรรม                      NaN
# 2                          ศูนย์ยาสี่แยกข่วงสิงห์                      NaN
# 3                                      เอสทีเภสัช                      NaN
# 4                                      ร้านบู๊ทส์  บู๊ทส์ - โลตัส เชิงทะเล
# ...                                           ...                      ...
# 9246                             กุดข้าวปุ้นเภสัช                      NaN
# 9247  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองบัวพัฒนา                      NaN
# 9248                              บ้านยาน้ำกระจาย                      NaN
# 9249           โรงพยาบาลมุกดาหารอินเตอร์เนชั่นแนล                      NaN
# 9250                      กองพยาบาล กรมแผนที่ทหาร                      NaN
#
#                         ประเภท         ตำบล               อำเภอ  \
# ...

# %% [markdown]
# #### ตัดเอาเฉพาะคอลัมน์ที่ต้องการ

# %%
data11 = data10[['ชื่อ','ประเภท','ตำบล','อำเภอ','จังหวัด']]
data11
# Out:
#                                              ชื่อ                    ประเภท  \
# 0                                     ร้านยาฟารุก                    ร้านยา
# 1                     อัสลามการแพทย์คลินิกเวชกรรม                    คลินิก
# 2                          ศูนย์ยาสี่แยกข่วงสิงห์                    ร้านยา
# 3                                      เอสทีเภสัช                    ร้านยา
# 4                                      ร้านบู๊ทส์                    ร้านยา
# ...                                           ...                       ...
# 9246                             กุดข้าวปุ้นเภสัช                    ร้านยา
# 9247  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองบัวพัฒนา  โรงพยาบาล/หน่วยงานภาครัฐ
# 9248                              บ้านยาน้ำกระจาย                    ร้านยา
# 9249           โรงพยาบาลมุกดาหารอินเตอร์เนชั่นแนล       หน่วยงานเอกชน/อื่นๆ
# 9250                      กองพยาบาล กรมแผนที่ทหาร                       NaN
#
#              ตำบล               อำเภอ        จังหวัด
# ...

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
data11.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง data11
#เนื่องจากมี True แสดงว่ามีค่าที่เป็น Missing จะทำการลบค่า Missing ต่อไป
# Out:
# ชื่อ       False
# ประเภท      True
# ตำบล        True
# อำเภอ       True
# จังหวัด     True
# dtype: bool

# %% [markdown]
# ####แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data_covid

# %%
data12 = data11.fillna(value={'ประเภท':'ไม่ทราบ','ตำบล':'ไม่ทราบ','อำเภอ':'ไม่ทราบ','จังหวัด':'ไม่ทราบ'}) #แทน missing ด้วยค่าที่เหมาะสม จากตาราง data11
data12 # แสดงตาราง mohpromt_updated
# Out:
#                                              ชื่อ                    ประเภท  \
# 0                                     ร้านยาฟารุก                    ร้านยา
# 1                     อัสลามการแพทย์คลินิกเวชกรรม                    คลินิก
# 2                          ศูนย์ยาสี่แยกข่วงสิงห์                    ร้านยา
# 3                                      เอสทีเภสัช                    ร้านยา
# 4                                      ร้านบู๊ทส์                    ร้านยา
# ...                                           ...                       ...
# 9246                             กุดข้าวปุ้นเภสัช                    ร้านยา
# 9247  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองบัวพัฒนา  โรงพยาบาล/หน่วยงานภาครัฐ
# 9248                              บ้านยาน้ำกระจาย                    ร้านยา
# 9249           โรงพยาบาลมุกดาหารอินเตอร์เนชั่นแนล       หน่วยงานเอกชน/อื่นๆ
# 9250                      กองพยาบาล กรมแผนที่ทหาร                   ไม่ทราบ
#
#              ตำบล               อำเภอ        จังหวัด
# ...

# %% [markdown]
# ####ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
data12.isnull().any() #ดูค่า Missing คอลัมน์ของตาราง mohpromt_updated หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# ชื่อ       False
# ประเภท     False
# ตำบล       False
# อำเภอ      False
# จังหวัด    False
# dtype: bool

# %% [markdown]
# ##ตัดข้อมูลที่ไม่ทราบจังหวัดออก

# %%
def nums(first_number, last_number, step=1): #ฟังก์ชั้นเรียกข้อมูลตามลำดับตั้งแต่เลขตัวแรกถึงตัวสุดท้ายโดยนับไปทีละ1
    return range(first_number, last_number+1, step) #ส่งข้อมูล

# %%
from pandas.core.indexes.base import Index #นำเข้า index

frames = [] #สร้างตัวเก็บข้อมูล

Index_province = Index(data12['จังหวัด']) #นำรายชื่อจังหวัดออกมา
Index_province = Index_province.drop('ไม่ทราบ') #เอาข้อมูลที่ไม่ปรากฏชื่อจังหวัดออก
Index_province = Index_province.drop_duplicates(keep='first') #โดยเก็บชื่อจังหวัดที่พบเป็นอันดับแรกไว้ที่ตัวแปร index_province

for i in nums(0, 76): #สร้างลูปให้ i เป็นเลขตั้งแต่ 0-76 คือแต่ละจังหวัดที่ 0-76 ของตาราง
  mp_province = data12[data12['จังหวัด'] == Index_province[i]] # ให้ mp_province คือ ตัวแปรที่แยกข้อมูล77จังหวัด
  mp_province = mp_province.head(1) # แยก mp_province ให้เหลือ 5 ข้อมูลแรกของแต่ละจังหวัด
  frames.append(mp_province) #นำข้อมูล 1 ข้อมูลของแต่ละจังหวัดเข้าไปไว้ใน frame

mohpromt_updated = pd.concat(frames) # รวมข้อมูล
mohpromt_updated # แสดงผล
# Out:
#                              ชื่อ  ประเภท       ตำบล               อำเภอ  \
# 0                     ร้านยาฟารุก  ร้านยา       แว้ง                แว้ง
# 1     อัสลามการแพทย์คลินิกเวชกรรม  คลินิก     บางอ้อ          เขตบางพลัด
# 2          ศูนย์ยาสี่แยกข่วงสิงห์  ร้านยา  ช้างเผือก      เมืองเชียงใหม่
# 3                      เอสทีเภสัช  ร้านยา    ในเมือง  เมืองนครศรีธรรมราช
# 4                      ร้านบู๊ทส์  ร้านยา   เชิงทะเล                ถลาง
# ...                           ...     ...        ...                 ...
# 1043                   ชัยยงเภสัช  ร้านยา  กาฬสินธุ์      เมืองกาฬสินธุ์
# 1185                เพรียว (Pure)  ร้านยา  หญ้าปล้อง       เมืองศรีสะเกษ
# 1518                แก้วอารีเภสัช  ร้านยา     บ้านนา              บ้านนา
# 1618                โพธิ์ทองโอสถ2  ร้านยา    เนินขาม             เนินขาม
# 2513               วัตสันฟาร์มาซี  ร้านยา     บางมัญ      เมืองสิงห์บุรี
#
#             จังหวัด
# 0          นราธิวาส
# 1     กรุงเทพมหานคร
# 2         เชียงใหม่
# ...

# %% [markdown]
# # ต่อตาราง data covid, data region และ mohpromt

# %%
covid_region_mohpromt = covid_region_updated.merge(mohpromt_updated,how='left',left_on = 'จังหวัด',right_on = 'จังหวัด') 
#เชื่อมตาราง 2 ตาราง คือ covid_region_updated และ mohpromt_updated

covid_region_mohpromt #แสดงตาราง
# Out:
#             No. announce_date      sex      age  \
# 0       2223436    2022-01-01      ชาย       39
# 1       2223437    2022-01-01     หญิง       39
# 2       2223438    2022-01-01      ชาย       64
# 3       2223439    2022-01-01      ชาย       27
# 4       2223440    2022-01-01     หญิง       35
# ...         ...           ...      ...      ...
# 913207  3136644    2022-03-11      ชาย  ไม่ทราบ
# 913208  3136645    2022-03-11      ชาย  ไม่ทราบ
# 913209  3136646    2022-03-11     หญิง  ไม่ทราบ
# 913210  3136647    2022-03-11     หญิง  ไม่ทราบ
# 913211  3136648    2022-03-11  ไม่ทราบ  ไม่ทราบ
#
#                                                risk province_of_onset  \
# 0                                             อื่นๆ             พะเยา
# 1       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 3       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
covid_region_mohpromt.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง covid_region_mohpromt
#เนื่องจากมี True แสดงว่ามีค่าที่เป็น Missing จะทำการลบค่า Missing ต่อไป
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# risk                      False
# province_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# ชื่อ                       True
# ประเภท                     True
# ตำบล                       True
# อำเภอ                      True
# dtype: bool

# %% [markdown]
# ####แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data_covid

# %%
covid_region_mohpromt_updated = covid_region_mohpromt.fillna(value={'ชื่อ':'ไม่ทราบ','ประเภท':'ไม่ทราบ','ตำบล':'ไม่ทราบ','อำเภอ':'ไม่ทราบ'}) 
#แทน missing ด้วยค่าที่เหมาะสม จากตาราง covid_region_mohpromt

covid_region_mohpromt_updated # แสดงตาราง covid_region_mohpromt_updated
# Out:
#             No. announce_date      sex      age  \
# 0       2223436    2022-01-01      ชาย       39
# 1       2223437    2022-01-01     หญิง       39
# 2       2223438    2022-01-01      ชาย       64
# 3       2223439    2022-01-01      ชาย       27
# 4       2223440    2022-01-01     หญิง       35
# ...         ...           ...      ...      ...
# 913207  3136644    2022-03-11      ชาย  ไม่ทราบ
# 913208  3136645    2022-03-11      ชาย  ไม่ทราบ
# 913209  3136646    2022-03-11     หญิง  ไม่ทราบ
# 913210  3136647    2022-03-11     หญิง  ไม่ทราบ
# 913211  3136648    2022-03-11  ไม่ทราบ  ไม่ทราบ
#
#                                                risk province_of_onset  \
# 0                                             อื่นๆ             พะเยา
# 1       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 3       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...

# %% [markdown]
# ####ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
covid_region_mohpromt_updated.isnull().any() #ดูค่า Missing คอลัมน์ของตาราง mohpromt_updated หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# risk                      False
# province_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# ชื่อ                      False
# ประเภท                    False
# ตำบล                      False
# อำเภอ                     False
# dtype: bool

# %% [markdown]
# # ตัดข้อมูลแต่ละแถว เพื่อ save file เพื่อทำ Dashboad

# %%
all_data1 = covid_region_mohpromt_updated[(covid_region_mohpromt_updated['announce_date']>='2022-01-01') & (covid_region_mohpromt_updated['announce_date']<='2022-01-15')]
all_data1
# Out:
#            No. announce_date   sex      age  \
# 0      2223436    2022-01-01   ชาย       39
# 1      2223437    2022-01-01  หญิง       39
# 2      2223438    2022-01-01   ชาย       64
# 3      2223439    2022-01-01   ชาย       27
# 4      2223440    2022-01-01  หญิง       35
# ...        ...           ...   ...      ...
# 92968  2316404    2022-01-15   ชาย  ไม่ทราบ
# 92969  2316405    2022-01-15   ชาย  ไม่ทราบ
# 92970  2316406    2022-01-15   ชาย  ไม่ทราบ
# 92971  2316407    2022-01-15   ชาย  ไม่ทราบ
# 92972  2316408    2022-01-15   ชาย  ไม่ทราบ
#
#                                               risk province_of_onset  จังหวัด  \
# 0                                            อื่นๆ             พะเยา    พะเยา
# 1      สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา    พะเยา
# 2      สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา    พะเยา
# 3      สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา    พะเยา
# ...

# %%
all_data2 = covid_region_mohpromt_updated[(covid_region_mohpromt_updated['announce_date']>='2022-01-16') & (covid_region_mohpromt_updated['announce_date']<='2022-01-31')]
all_data2
# Out:
#             No. announce_date   sex      age  \
# 92973   2316409    2022-01-16   ชาย       29
# 92974   2316410    2022-01-16   ชาย       27
# 92975   2316411    2022-01-16   ชาย       20
# 92976   2316412    2022-01-16  หญิง       34
# 92977   2316413    2022-01-16  หญิง       35
# ...         ...           ...   ...      ...
# 217102  2440538    2022-01-31   ชาย  ไม่ทราบ
# 217103  2440539    2022-01-31   ชาย  ไม่ทราบ
# 217104  2440540    2022-01-31   ชาย  ไม่ทราบ
# 217105  2440541    2022-01-31   ชาย  ไม่ทราบ
# 217106  2440542    2022-01-31   ชาย  ไม่ทราบ
#
#                                                risk province_of_onset  \
# 92973                                         อื่นๆ          เชียงราย
# 92974   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          เชียงราย
# 92975                                         อื่นๆ          เชียงราย
# 92976                                         อื่นๆ          เชียงราย
# ...

# %%
all_data3 = covid_region_mohpromt_updated[(covid_region_mohpromt_updated['announce_date']>='2022-02-01') & (covid_region_mohpromt_updated['announce_date']<='2022-02-15')]
all_data3
# Out:
#             No. announce_date   sex      age  \
# 217107  2440543    2022-02-01  หญิง       35
# 217108  2440544    2022-02-01  หญิง       19
# 217109  2440545    2022-02-01  หญิง        8
# 217110  2440546    2022-02-01  หญิง       44
# 217111  2440547    2022-02-01   ชาย       44
# ...         ...           ...   ...      ...
# 399160  2622596    2022-02-15   ชาย  ไม่ทราบ
# 399161  2622597    2022-02-15   ชาย  ไม่ทราบ
# 399162  2622598    2022-02-15   ชาย  ไม่ทราบ
# 399163  2622599    2022-02-15   ชาย  ไม่ทราบ
# 399164  2622600    2022-02-15   ชาย  ไม่ทราบ
#
#                                                risk province_of_onset  \
# 217107                                        อื่นๆ             พะเยา
# 217108  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 217109  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 217110  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...

# %%
all_data4 = covid_region_mohpromt_updated[(covid_region_mohpromt_updated['announce_date']>='2022-02-16') & (covid_region_mohpromt_updated['announce_date']<='2022-02-28')]
all_data4
# Out:
#             No. announce_date   sex      age  \
# 399165  2622601    2022-02-16   ชาย       28
# 399166  2622602    2022-02-16  หญิง       73
# 399167  2622603    2022-02-16  หญิง       10
# 399168  2622604    2022-02-16  หญิง       41
# 399169  2622605    2022-02-16  หญิง       51
# ...         ...           ...   ...      ...
# 668486  2891923    2022-02-28   ชาย  ไม่ทราบ
# 668487  2891924    2022-02-28   ชาย  ไม่ทราบ
# 668488  2891925    2022-02-28   ชาย  ไม่ทราบ
# 668489  2891926    2022-02-28   ชาย  ไม่ทราบ
# 668490  2891927    2022-02-28   ชาย  ไม่ทราบ
#
#                                                risk province_of_onset  \
# 399165              บุคลากรด้านการแพทย์และสาธารณสุข             พะเยา
# 399166  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 399167  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 399168  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...

# %%
all_data5 = covid_region_mohpromt_updated[(covid_region_mohpromt_updated['announce_date']>='2022-03-01') & (covid_region_mohpromt_updated['announce_date']<='2022-03-11')]
all_data5
# Out:
#             No. announce_date      sex      age  \
# 668491  2891928    2022-03-01      ชาย  ไม่ทราบ
# 668492  2891929    2022-03-01     หญิง  ไม่ทราบ
# 668493  2891930    2022-03-01     หญิง  ไม่ทราบ
# 668494  2891931    2022-03-01     หญิง  ไม่ทราบ
# 668495  2891932    2022-03-01     หญิง  ไม่ทราบ
# ...         ...           ...      ...      ...
# 913207  3136644    2022-03-11      ชาย  ไม่ทราบ
# 913208  3136645    2022-03-11      ชาย  ไม่ทราบ
# 913209  3136646    2022-03-11     หญิง  ไม่ทราบ
# 913210  3136647    2022-03-11     หญิง  ไม่ทราบ
# 913211  3136648    2022-03-11  ไม่ทราบ  ไม่ทราบ
#
#                                                risk province_of_onset  \
# 668491                                        อื่นๆ        แม่ฮ่องสอน
# 668492  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        แม่ฮ่องสอน
# 668493  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        แม่ฮ่องสอน
# 668494              บุคลากรด้านการแพทย์และสาธารณสุข        แม่ฮ่องสอน
# ...

# %% [markdown]
# # Save file

# %%
all_data1.to_csv('data1.csv', encoding='utf-8')

# %%
all_data2.to_csv('data2.csv', encoding='utf-8')

# %%
all_data3.to_csv('data3.csv', encoding='utf-8')

# %%
all_data4.to_csv('data4.csv', encoding='utf-8')

# %%
all_data5.to_csv('data5.csv', encoding='utf-8')
