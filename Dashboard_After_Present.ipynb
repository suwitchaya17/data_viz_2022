# %% [markdown]
# <a href="https://colab.research.google.com/github/suwitchaya17/data_viz_2022/blob/main/Dashboard_After_Present.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #เตรียมข้อมูล
#
# กำหนดช่วงวันที่จากคนละครึ่งทั้ง 4 เฟส ได้แก่
# - เฟส 1 2020-10-23 ถึง 2020-12-31
# - เฟส 2 2021-01-01 ถึง 2021-03-31
# - เฟส 3 2021-10-01 ถึง 2021-10-16
# - เฟส 4 2022-02-01 ถึง 2022-02-16

# %% [markdown]
# # *Data Covid

# %%
import pandas as pd  #ทำงานกับข้อมูลลักษณะตาราง
import os  #จัดการไฟล์และ path

# %%
from google.colab import drive  #เชื่อม google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/covid_data'   #pathจะชี้ไปยังโฟล์เดอร์
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## ชุด 1 : 2020-01-12 ถึง 2021-08-11

# %%
data_file_path1 = os.path.join(path,'confirmed-cases.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(data_file_path1)
# Out:
# /content/drive/My Drive/covid_data/confirmed-cases.xlsx

# %%
data_covid1 = pd.read_excel(data_file_path1)  #กำหนดตัวแปร data_covid1 เป็นข้อมูลของผู้ป่วยโควิด
data_covid1  #เรียกดูตารางของผู้ป่วยโควิด
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1            2    2020-01-17           NaT  หญิง  74.0   ปี       China
# 2            3    2020-01-22           NaT  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22           NaT   ชาย  68.0   ปี       China
# 4            5    2020-01-24           NaT  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985    2021-08-11    2021-08-10  หญิง   8.0   ปี    Thailand
# 816985  816986    2021-08-11    2021-08-10   ชาย  14.0   ปี    Thailand
# 816986  816987    2021-08-11    2021-08-10   ชาย  59.0   ปี    Thailand
# 816987  816988    2021-08-11    2021-08-10  หญิง  34.0   ปี    Thailand
# 816988  816989    2021-08-11    2021-08-10  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 2                  เมือง
# 3                    NaN
# 4                    NaN
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %% [markdown]
# ## ชุด 2 :  2021-08-12 ถึง 2021-10-25

# %%
data_file_path2 = os.path.join(path,'confirmed-cases-since-120864.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(data_file_path2)
# Out:
# /content/drive/My Drive/covid_data/confirmed-cases-since-120864.xlsx

# %%
data_covid2 = pd.read_excel(data_file_path2)  #กำหนดตัวแปร data_covid2 เป็นข้อมูลของผู้ป่วยโควิด
data_covid2  #เรียกดูตารางของผู้ป่วยโควิด
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990    2021-08-12    2021-08-11   ชาย   7.0   ปี    Thailand
# 1         816991    2021-08-12    2021-08-11   ชาย   1.0   ปี    Thailand
# 2         816992    2021-08-12    2021-08-11   ชาย  35.0   ปี    Thailand
# 3         816993    2021-08-12    2021-08-11  หญิง  33.0   ปี    Thailand
# 4         816994    2021-08-12    2021-08-11  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    2021-10-25    2021-10-24   ชาย  45.0   ปี         NaN
# 1042164  1859154    2021-10-25    2021-10-24   ชาย  31.0   ปี         NaN
# 1042165  1859155    2021-10-25    2021-10-24   ชาย  31.0   ปี         NaN
# 1042166  1859156    2021-10-25    2021-10-24   ชาย  24.0   ปี         NaN
# 1042167  1859157    2021-10-25    2021-10-24   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ## ชุด 3 :  2021-10-26 ถึง 2022-02-27

# %%
data_file_path3 = os.path.join(path,'confirmed-cases-since-271064.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(data_file_path3)
# Out:
# /content/drive/My Drive/covid_data/confirmed-cases-since-271064.xlsx

# %%
data_covid3 = pd.read_excel(data_file_path3)  #กำหนดตัวแปร data_covid3 เป็นข้อมูลของผู้ป่วยโควิด
data_covid3  #เรียกดูตารางของผู้ป่วยโควิด
# Out:
#              No. announce_date Notified date   sex  age Unit nationality  \
# 0        1859158    2021-10-26    2021-10-25   ชาย   20   ปี    Thailand
# 1        1859159    2021-10-26    2021-10-25  หญิง   42   ปี    Thailand
# 2        1859160    2021-10-26    2021-10-25  หญิง   33   ปี    Thailand
# 3        1859161    2021-10-26    2021-10-25  หญิง   52   ปี    Thailand
# 4        1859162    2021-10-26    2021-10-25  หญิง   84   ปี    Thailand
# ...          ...           ...           ...   ...  ...  ...         ...
# 1010454  2869612    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010455  2869613    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010456  2869614    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010457  2869615    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010458  2869616    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                   ลำปาง        เมืองลำปาง
# 1                   ลำปาง        เมืองลำปาง
# 2                   ลำปาง          ห้างฉัตร
# 3                   ลำปาง          ห้างฉัตร
# 4                   ลำปาง        เมืองลำปาง
# ...                   ...               ...
# 1010454               NaN               NaN
# 1010455               NaN               NaN
# 1010456               NaN               NaN
# 1010457               NaN               NaN
# 1010458               NaN               NaN
#
# [1010459 rows x 11 columns]

# %% [markdown]
# ## ชุด 4 :  2022-02-28 ถึง 2022-03-23

# %%
data_file_path4 = os.path.join(path,'confirmed-cases-since-280265.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(data_file_path4)
# Out:
# /content/drive/My Drive/covid_data/confirmed-cases-since-280265.xlsx

# %%
data_covid4 = pd.read_excel(data_file_path4)  #กำหนดตัวแปร data_covid4 เป็นข้อมูลของผู้ป่วยโควิด
data_covid4  #เรียกดูตารางของผู้ป่วยโควิด
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617    2022-02-28    2022-02-27   ชาย  41.0   ปี    Thailand
# 1       2869618    2022-02-28    2022-02-27  หญิง  45.0   ปี    Thailand
# 2       2869619    2022-02-28    2022-02-27  หญิง  40.0   ปี    Thailand
# 3       2869620    2022-02-28    2022-02-27   ชาย  44.0   ปี    Thailand
# 4       2869621    2022-02-28    2022-02-27   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 554335  3423952    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554336  3423953    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554337  3423954    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554338  3423955    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554339  3423956    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 554335         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 554336         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 554337         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 554338         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 554339             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 554335               NaN               NaN
# 554336               NaN               NaN
# 554337               NaN               NaN
# 554338               NaN               NaN
# 554339               NaN               NaN
#
# [554340 rows x 11 columns]

# %% [markdown]
# ### ต่อตาราง ชุด 1 และ ชุด 2

# %%
covid1 = pd.concat([data_covid1,data_covid2])
covid1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0              1    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1              2    2020-01-17           NaT  หญิง  74.0   ปี       China
# 2              3    2020-01-22           NaT  หญิง  73.0   ปี    Thailand
# 3              4    2020-01-22           NaT   ชาย  68.0   ปี       China
# 4              5    2020-01-24           NaT  หญิง  66.0   ปี       China
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    2021-10-25    2021-10-24   ชาย  45.0   ปี         NaN
# 1042164  1859154    2021-10-25    2021-10-24   ชาย  31.0   ปี         NaN
# 1042165  1859155    2021-10-25    2021-10-24   ชาย  31.0   ปี         NaN
# 1042166  1859156    2021-10-25    2021-10-24   ชาย  24.0   ปี         NaN
# 1042167  1859157    2021-10-25    2021-10-24   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                              risk  \
# 0               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                      นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3               กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                     นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                       ...                               ...
# 1042163         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0           กรุงเทพมหานคร               NaN
# 1           กรุงเทพมหานคร               NaN
# 2                  นครปฐม             เมือง
# 3           กรุงเทพมหานคร               NaN
# 4           กรุงเทพมหานคร               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1859157 rows x 11 columns]

# %% [markdown]
# ### ต่อตาราง ชุด 3 และ ชุด 4

# %%
covid2 = pd.concat([data_covid3,data_covid4])
covid2
# Out:
#             No. announce_date Notified date   sex  age Unit nationality  \
# 0       1859158    2021-10-26    2021-10-25   ชาย   20   ปี    Thailand
# 1       1859159    2021-10-26    2021-10-25  หญิง   42   ปี    Thailand
# 2       1859160    2021-10-26    2021-10-25  หญิง   33   ปี    Thailand
# 3       1859161    2021-10-26    2021-10-25  หญิง   52   ปี    Thailand
# 4       1859162    2021-10-26    2021-10-25  หญิง   84   ปี    Thailand
# ...         ...           ...           ...   ...  ...  ...         ...
# 554335  3423952    2022-03-23    2022-03-22   ชาย  NaN  NaN         NaN
# 554336  3423953    2022-03-23    2022-03-22   ชาย  NaN  NaN         NaN
# 554337  3423954    2022-03-23    2022-03-22   ชาย  NaN  NaN         NaN
# 554338  3423955    2022-03-23    2022-03-22   ชาย  NaN  NaN         NaN
# 554339  3423956    2022-03-23    2022-03-22   ชาย  NaN  NaN         NaN
#
#        province_of_isolation                                           risk  \
# 0                      ลำปาง                                          อื่นๆ
# 1                      ลำปาง                                          อื่นๆ
# 2                      ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                      ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                      ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                            ...
# 554335         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 554336         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 554337         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 554338         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 554339             เชียงใหม่                               ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  ลำปาง        เมืองลำปาง
# 1                  ลำปาง        เมืองลำปาง
# 2                  ลำปาง          ห้างฉัตร
# 3                  ลำปาง          ห้างฉัตร
# 4                  ลำปาง        เมืองลำปาง
# ...                  ...               ...
# 554335               NaN               NaN
# 554336               NaN               NaN
# 554337               NaN               NaN
# 554338               NaN               NaN
# 554339               NaN               NaN
#
# [1564799 rows x 11 columns]

# %% [markdown]
# ### ต่อตารางทั้ง 4 ชุด

# %%
covid_all = pd.concat([covid1,covid2])
covid_all
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1             2    2020-01-17           NaT  หญิง  74.0   ปี       China
# 2             3    2020-01-22           NaT  หญิง  73.0   ปี    Thailand
# 3             4    2020-01-22           NaT   ชาย  68.0   ปี       China
# 4             5    2020-01-24           NaT  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 554335  3423952    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554336  3423953    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554337  3423954    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554338  3423955    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
# 554339  3423956    2022-03-23    2022-03-22   ชาย   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 554335         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 554336         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 554337         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 554338         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 554339             เชียงใหม่                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 554335               NaN               NaN
# 554336               NaN               NaN
# 554337               NaN               NaN
# 554338               NaN               NaN
# 554339               NaN               NaN
#
# [3423956 rows x 11 columns]

# %% [markdown]
# ### ตัดเอาเฉพาะคอลัมน์ที่ต้องการ

# %%
covid_new = covid_all[['No.','announce_date','sex','age','risk','province_of_onset']]
covid_new
# Out:
#             No. announce_date   sex   age                              risk  \
# 0             1    2020-01-12  หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1             2    2020-01-17  หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2             3    2020-01-22  หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3             4    2020-01-22   ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4             5    2020-01-24  หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...         ...           ...   ...   ...                               ...
# 554335  3423952    2022-03-23   ชาย   NaN                  ทัณฑสถาน/เรือนจำ
# 554336  3423953    2022-03-23   ชาย   NaN                  ทัณฑสถาน/เรือนจำ
# 554337  3423954    2022-03-23   ชาย   NaN                  ทัณฑสถาน/เรือนจำ
# 554338  3423955    2022-03-23   ชาย   NaN                  ทัณฑสถาน/เรือนจำ
# 554339  3423956    2022-03-23   ชาย   NaN                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset
# 0          กรุงเทพมหานคร
# 1          กรุงเทพมหานคร
# 2                 นครปฐม
# 3          กรุงเทพมหานคร
# 4          กรุงเทพมหานคร
# ...                  ...
# 554335               NaN
# 554336               NaN
# 554337               NaN
# 554338               NaN
# 554339               NaN
#
# [3423956 rows x 6 columns]

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
covid_new.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง covid_new
#เนื่องจากมี True แสดงว่ามีค่าที่เป็น Missing จะทำการลบค่า Missing ต่อไป
# Out:
# No.                  False
# announce_date        False
# sex                   True
# age                   True
# risk                  True
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ####แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data_covid

# %%
covid1_updated = covid_new.fillna(value={'No.':'ไม่ทราบ','announce_date':'ไม่ทราบ','sex':'ไม่ทราบ','age':'ไม่ทราบ','risk':'ไม่ทราบ'}) #แทน missing ด้วยค่าที่เหมาะสม จากตาราง covid_new
covid1_updated # แสดงตาราง covid1_updated
# Out:
#             No. announce_date   sex      age  \
# 0             1    2020-01-12  หญิง     61.0
# 1             2    2020-01-17  หญิง     74.0
# 2             3    2020-01-22  หญิง     73.0
# 3             4    2020-01-22   ชาย     68.0
# 4             5    2020-01-24  หญิง     66.0
# ...         ...           ...   ...      ...
# 554335  3423952    2022-03-23   ชาย  ไม่ทราบ
# 554336  3423953    2022-03-23   ชาย  ไม่ทราบ
# 554337  3423954    2022-03-23   ชาย  ไม่ทราบ
# 554338  3423955    2022-03-23   ชาย  ไม่ทราบ
# 554339  3423956    2022-03-23   ชาย  ไม่ทราบ
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                  ...               ...
# 554335                  ทัณฑสถาน/เรือนจำ               NaN
# 554336                  ทัณฑสถาน/เรือนจำ               NaN
# 554337                  ทัณฑสถาน/เรือนจำ               NaN
# 554338                  ทัณฑสถาน/เรือนจำ               NaN
# 554339                  ทัณฑสถาน/เรือนจำ               NaN
#
# [3423956 rows x 6 columns]

# %%
covid_updated= covid1_updated.dropna() #ตัดค่าว่างออกของคอมลัมน์จังหวัด
covid_updated
# Out:
#             No. announce_date   sex   age  \
# 0             1    2020-01-12  หญิง  61.0
# 1             2    2020-01-17  หญิง  74.0
# 2             3    2020-01-22  หญิง  73.0
# 3             4    2020-01-22   ชาย  68.0
# 4             5    2020-01-24  หญิง  66.0
# ...         ...           ...   ...   ...
# 554292  3423909    2022-03-23   ชาย  59.0
# 554293  3423910    2022-03-23   ชาย  42.0
# 554294  3423911    2022-03-23   ชาย  60.0
# 554295  3423912    2022-03-23  หญิง  21.0
# 554296  3423913    2022-03-23   ชาย  39.0
#
#                                            risk province_of_onset
# 0              คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1              คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2              คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3              คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4              คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                         ...               ...
# 554292  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 554293  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 554294  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 554295  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 554296  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
#
# [3011263 rows x 6 columns]

# %% [markdown]
# ####ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
covid_updated.isnull().any() #ดูค่า Missing คอลัมน์ของตาราง covid_updated หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                  False
# announce_date        False
# sex                  False
# age                  False
# risk                 False
# province_of_onset    False
# dtype: bool

# %% [markdown]
# # *Data region

# %%
data_region = { 'จังหวัด':['อำนาจเจริญ','บึงกาฬ','บุรีรัมย์','ชัยภูมิ','กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม','มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู','หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ','สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร'
              ,'เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี'
              ,'ปทุมธานี', 'สมุทรปราการ', 'สมุทรสาคร', 'สมุทรสงคราม', 'สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา'
              ,'กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],    #column 1 -> จังหวัด
              '6 ภูมิภาค (ภูมิศาสตร์)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก'
              ,'กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],   #column 2 -> 6 ภูมิภาค (ภูมิศาสตร์)
              '4 ภูมิภาค (การเมือง)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],   #column 3 -> 4 ภูมิภาค (การเมือง)
              '6 ภูมิภาค (อุตุนิยมวิทยา)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย'
              ,'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'
              ,'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'],     #column 4 -> 6 ภูมิภาค (อุตุนิยมวิทยา)	
              '5 ภูมิภาค (การท่องเที่ยว)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']     #column 5 -> 5 ภูมิภาค (การท่องเที่ยว)
}

# %% [markdown]
# ### ตาราง data6 : ข้อมูลภูมิภาคของประเทศไทย

# %%
region1 = pd.DataFrame.from_dict(data_region)   #กำหนดตัวแปร region1 เป็นข้อมูลภูมิภาคของประเทศไทย
region1 #เรียกดูตารางภูมิภาคของประเทศไทย
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# ..         ...                    ...                  ...
# 72       พังงา                    ใต้                  ใต้
# 73      ภูเก็ต                    ใต้                  ใต้
# 74       ระนอง                    ใต้                  ใต้
# 75        สตูล                    ใต้                  ใต้
# 76        ตรัง                    ใต้                  ใต้
#
#          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)
# 0               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 1               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 3               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 4               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# ..                             ...                       ...
# 72  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 73  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 74  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 75  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 76  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
#
# [77 rows x 5 columns]

# %% [markdown]
# #### ตัดเอาเฉพาะคอลัมน์ที่ต้องการ

# %%
region_updated = region1[['จังหวัด','6 ภูมิภาค (ภูมิศาสตร์)']]
region_updated
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# # **ต่อตาราง data covid และ data region

# %%
covid_region = covid_updated.merge(region_updated,how='left',left_on = 'province_of_onset',right_on = 'จังหวัด') #เชื่อมตาราง 2 ตาราง คือ covid_updated และ region_updated
covid_region  #แสดงตาราง
# Out:
#              No. announce_date   sex   age  \
# 0              1    2020-01-12  หญิง  61.0
# 1              2    2020-01-17  หญิง  74.0
# 2              3    2020-01-22  หญิง  73.0
# 3              4    2020-01-22   ชาย  68.0
# 4              5    2020-01-24  หญิง  66.0
# ...          ...           ...   ...   ...
# 3011258  3423909    2022-03-23   ชาย  59.0
# 3011259  3423910    2022-03-23   ชาย  42.0
# 3011260  3423911    2022-03-23   ชาย  60.0
# 3011261  3423912    2022-03-23  หญิง  21.0
# 3011262  3423913    2022-03-23   ชาย  39.0
#
#                                             risk province_of_onset  \
# 0               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2               คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                          ...               ...
# 3011258  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011259  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011260  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011261  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011262  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
#
#                จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0        กรุงเทพมหานคร                   กลาง
# 1        กรุงเทพมหานคร                   กลาง
# 2               นครปฐม                   กลาง
# 3        กรุงเทพมหานคร                   กลาง
# 4        กรุงเทพมหานคร                   กลาง
# ...                ...                    ...
# 3011258  กรุงเทพมหานคร                   กลาง
# 3011259  กรุงเทพมหานคร                   กลาง
# 3011260  กรุงเทพมหานคร                   กลาง
# 3011261  กรุงเทพมหานคร                   กลาง
# 3011262  กรุงเทพมหานคร                   กลาง
#
# [3011263 rows x 8 columns]

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
covid_region.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง covid_region
#เนื่องจากมี True แสดงว่ามีค่าที่เป็น Missing จะทำการลบค่า Missing ต่อไป
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# risk                      False
# province_of_onset         False
# จังหวัด                    True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %% [markdown]
# ####แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง covid_region

# %%
covid_region_1 = covid_region.fillna(value={'6 ภูมิภาค (ภูมิศาสตร์)':'ไม่ทราบ'}) #แทน missing ด้วยค่าที่เหมาะสม จากตาราง covid_region
covid_region_1 # แสดงตาราง covid_region_1
# Out:
#              No. announce_date   sex   age  \
# 0              1    2020-01-12  หญิง  61.0
# 1              2    2020-01-17  หญิง  74.0
# 2              3    2020-01-22  หญิง  73.0
# 3              4    2020-01-22   ชาย  68.0
# 4              5    2020-01-24  หญิง  66.0
# ...          ...           ...   ...   ...
# 3011258  3423909    2022-03-23   ชาย  59.0
# 3011259  3423910    2022-03-23   ชาย  42.0
# 3011260  3423911    2022-03-23   ชาย  60.0
# 3011261  3423912    2022-03-23  หญิง  21.0
# 3011262  3423913    2022-03-23   ชาย  39.0
#
#                                             risk province_of_onset  \
# 0               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2               คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                          ...               ...
# 3011258  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011259  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011260  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011261  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011262  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
#
#                จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0        กรุงเทพมหานคร                   กลาง
# 1        กรุงเทพมหานคร                   กลาง
# 2               นครปฐม                   กลาง
# 3        กรุงเทพมหานคร                   กลาง
# 4        กรุงเทพมหานคร                   กลาง
# ...                ...                    ...
# 3011258  กรุงเทพมหานคร                   กลาง
# 3011259  กรุงเทพมหานคร                   กลาง
# 3011260  กรุงเทพมหานคร                   กลาง
# 3011261  กรุงเทพมหานคร                   กลาง
# 3011262  กรุงเทพมหานคร                   กลาง
#
# [3011263 rows x 8 columns]

# %%
covid_region_updated = covid_region_1.dropna() #ตัดค่าว่างออกของคอมลัมน์จังหวัด
covid_region_updated
# Out:
#              No. announce_date   sex   age  \
# 0              1    2020-01-12  หญิง  61.0
# 1              2    2020-01-17  หญิง  74.0
# 2              3    2020-01-22  หญิง  73.0
# 3              4    2020-01-22   ชาย  68.0
# 4              5    2020-01-24  หญิง  66.0
# ...          ...           ...   ...   ...
# 3011258  3423909    2022-03-23   ชาย  59.0
# 3011259  3423910    2022-03-23   ชาย  42.0
# 3011260  3423911    2022-03-23   ชาย  60.0
# 3011261  3423912    2022-03-23  หญิง  21.0
# 3011262  3423913    2022-03-23   ชาย  39.0
#
#                                             risk province_of_onset  \
# 0               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2               คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                          ...               ...
# 3011258  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011259  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011260  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011261  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011262  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
#
#                จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0        กรุงเทพมหานคร                   กลาง
# 1        กรุงเทพมหานคร                   กลาง
# 2               นครปฐม                   กลาง
# 3        กรุงเทพมหานคร                   กลาง
# 4        กรุงเทพมหานคร                   กลาง
# ...                ...                    ...
# 3011258  กรุงเทพมหานคร                   กลาง
# 3011259  กรุงเทพมหานคร                   กลาง
# 3011260  กรุงเทพมหานคร                   กลาง
# 3011261  กรุงเทพมหานคร                   กลาง
# 3011262  กรุงเทพมหานคร                   กลาง
#
# [3005751 rows x 8 columns]

# %% [markdown]
# ####ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
covid_region_updated.isnull().any() #ดูค่า Missing คอลัมน์ของตาราง covid_region_updated หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# risk                      False
# province_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# dtype: bool

# %% [markdown]
# # *Data รายชื่อหน่วยงานที่เข้าร่วมโครงการหมอพร้อม

# %%
import pandas as pd  #ทำงานกับข้อมูลลักษณะตาราง
import os  #จัดการไฟล์และ path

# %%
from google.colab import drive  #เชื่อม google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/mohpromt_data'   #pathจะชี้ไปยังโฟล์เดอร์
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mohpromt = os.path.join(path,'MOHPROMT.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(mohpromt)
# Out:
# /content/drive/My Drive/mohpromt_data/MOHPROMT.xlsx

# %% [markdown]
# ### ตาราง data_mohpromt : ข้อมูลรายชื่อหน่วยงานที่เข้าร่วมโครงการหมอพร้อม

# %%
data_mohpromt = pd.read_excel(mohpromt)  #กำหนดตัวแปร data_mohpromt  เป็นข้อมูลของรายชื่อหน่วยงานที่เข้าร่วมโครงการหมอพร้อม
data_mohpromt #เรียกดูตารางของรายชื่อหน่วยงานที่เข้าร่วมโครงการหมอพร้อม
# Out:
#                                              ชื่อ                     สาขา  \
# 0                                     ร้านยาฟารุก                     แว้ง
# 1                     อัสลามการแพทย์คลินิกเวชกรรม                      NaN
# 2                          ศูนย์ยาสี่แยกข่วงสิงห์                      NaN
# 3                                      เอสทีเภสัช                      NaN
# 4                                      ร้านบู๊ทส์  บู๊ทส์ - โลตัส เชิงทะเล
# ...                                           ...                      ...
# 9246                             กุดข้าวปุ้นเภสัช                      NaN
# 9247  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองบัวพัฒนา                      NaN
# 9248                              บ้านยาน้ำกระจาย                      NaN
# 9249           โรงพยาบาลมุกดาหารอินเตอร์เนชั่นแนล                      NaN
# 9250                      กองพยาบาล กรมแผนที่ทหาร                      NaN
#
#                         ประเภท         ตำบล               อำเภอ  \
# 0                       ร้านยา         แว้ง                แว้ง
# 1                       คลินิก       บางอ้อ          เขตบางพลัด
# 2                       ร้านยา    ช้างเผือก      เมืองเชียงใหม่
# 3                       ร้านยา      ในเมือง  เมืองนครศรีธรรมราช
# 4                       ร้านยา     เชิงทะเล                ถลาง
# ...                        ...          ...                 ...
# 9246                    ร้านยา     ข้าวปุ้น         กุดข้าวปุ้น
# 9247  โรงพยาบาล/หน่วยงานภาครัฐ      น้ำอ้อม          เกษตรวิสัย
# 9248                    ร้านยา         พะวง          เมืองสงขลา
# 9249       หน่วยงานเอกชน/อื่นๆ  ศรีบุญเรือง       เมืองมุกดาหาร
# 9250                       NaN          NaN                 NaN
#
#             จังหวัด  นำทาง
# 0          นราธิวาส  นำทาง
# 1     กรุงเทพมหานคร  นำทาง
# 2         เชียงใหม่  นำทาง
# 3     นครศรีธรรมราช    NaN
# 4            ภูเก็ต  นำทาง
# ...             ...    ...
# 9246    อุบลราชธานี  นำทาง
# 9247       ร้อยเอ็ด    NaN
# 9248          สงขลา  นำทาง
# 9249       มุกดาหาร    NaN
# 9250            NaN    NaN
#
# [9251 rows x 7 columns]

# %% [markdown]
# #### ตัดเอาเฉพาะคอลัมน์ที่ต้องการ

# %%
mohpromt1 = data_mohpromt[['ชื่อ','ประเภท','ตำบล','อำเภอ','จังหวัด']]
mohpromt1
# Out:
#                                              ชื่อ                    ประเภท  \
# 0                                     ร้านยาฟารุก                    ร้านยา
# 1                     อัสลามการแพทย์คลินิกเวชกรรม                    คลินิก
# 2                          ศูนย์ยาสี่แยกข่วงสิงห์                    ร้านยา
# 3                                      เอสทีเภสัช                    ร้านยา
# 4                                      ร้านบู๊ทส์                    ร้านยา
# ...                                           ...                       ...
# 9246                             กุดข้าวปุ้นเภสัช                    ร้านยา
# 9247  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองบัวพัฒนา  โรงพยาบาล/หน่วยงานภาครัฐ
# 9248                              บ้านยาน้ำกระจาย                    ร้านยา
# 9249           โรงพยาบาลมุกดาหารอินเตอร์เนชั่นแนล       หน่วยงานเอกชน/อื่นๆ
# 9250                      กองพยาบาล กรมแผนที่ทหาร                       NaN
#
#              ตำบล               อำเภอ        จังหวัด
# 0            แว้ง                แว้ง       นราธิวาส
# 1          บางอ้อ          เขตบางพลัด  กรุงเทพมหานคร
# 2       ช้างเผือก      เมืองเชียงใหม่      เชียงใหม่
# 3         ในเมือง  เมืองนครศรีธรรมราช  นครศรีธรรมราช
# 4        เชิงทะเล                ถลาง         ภูเก็ต
# ...           ...                 ...            ...
# 9246     ข้าวปุ้น         กุดข้าวปุ้น    อุบลราชธานี
# 9247      น้ำอ้อม          เกษตรวิสัย       ร้อยเอ็ด
# 9248         พะวง          เมืองสงขลา          สงขลา
# 9249  ศรีบุญเรือง       เมืองมุกดาหาร       มุกดาหาร
# 9250          NaN                 NaN            NaN
#
# [9251 rows x 5 columns]

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
mohpromt1.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง mohpromt1
#เนื่องจากมี True แสดงว่ามีค่าที่เป็น Missing จะทำการลบค่า Missing ต่อไป
# Out:
# ชื่อ       False
# ประเภท      True
# ตำบล        True
# อำเภอ       True
# จังหวัด     True
# dtype: bool

# %% [markdown]
# ####แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data_covid

# %%
mohpromt2 = mohpromt1.fillna(value={'ประเภท':'ไม่ทราบ','ตำบล':'ไม่ทราบ','อำเภอ':'ไม่ทราบ','จังหวัด':'ไม่ทราบ'}) #แทน missing ด้วยค่าที่เหมาะสม จากตาราง mohpromt1
mohpromt2 # แสดงตาราง mohpromt2
# Out:
#                                              ชื่อ                    ประเภท  \
# 0                                     ร้านยาฟารุก                    ร้านยา
# 1                     อัสลามการแพทย์คลินิกเวชกรรม                    คลินิก
# 2                          ศูนย์ยาสี่แยกข่วงสิงห์                    ร้านยา
# 3                                      เอสทีเภสัช                    ร้านยา
# 4                                      ร้านบู๊ทส์                    ร้านยา
# ...                                           ...                       ...
# 9246                             กุดข้าวปุ้นเภสัช                    ร้านยา
# 9247  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองบัวพัฒนา  โรงพยาบาล/หน่วยงานภาครัฐ
# 9248                              บ้านยาน้ำกระจาย                    ร้านยา
# 9249           โรงพยาบาลมุกดาหารอินเตอร์เนชั่นแนล       หน่วยงานเอกชน/อื่นๆ
# 9250                      กองพยาบาล กรมแผนที่ทหาร                   ไม่ทราบ
#
#              ตำบล               อำเภอ        จังหวัด
# 0            แว้ง                แว้ง       นราธิวาส
# 1          บางอ้อ          เขตบางพลัด  กรุงเทพมหานคร
# 2       ช้างเผือก      เมืองเชียงใหม่      เชียงใหม่
# 3         ในเมือง  เมืองนครศรีธรรมราช  นครศรีธรรมราช
# 4        เชิงทะเล                ถลาง         ภูเก็ต
# ...           ...                 ...            ...
# 9246     ข้าวปุ้น         กุดข้าวปุ้น    อุบลราชธานี
# 9247      น้ำอ้อม          เกษตรวิสัย       ร้อยเอ็ด
# 9248         พะวง          เมืองสงขลา          สงขลา
# 9249  ศรีบุญเรือง       เมืองมุกดาหาร       มุกดาหาร
# 9250      ไม่ทราบ             ไม่ทราบ        ไม่ทราบ
#
# [9251 rows x 5 columns]

# %% [markdown]
# ####ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
mohpromt2.isnull().any() #ดูค่า Missing คอลัมน์ของตาราง mohpromt2 หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# ชื่อ       False
# ประเภท     False
# ตำบล       False
# อำเภอ      False
# จังหวัด    False
# dtype: bool

# %% [markdown]
# ##ตัดข้อมูลที่ไม่ทราบจังหวัดออก

# %%
def nums(first_number, last_number, step=1): #ฟังก์ชั้นเรียกข้อมูลตามลำดับตั้งแต่เลขตัวแรกถึงตัวสุดท้ายโดยนับไปทีละ1
    return range(first_number, last_number+1, step) #ส่งข้อมูล

# %%
from pandas.core.indexes.base import Index #นำเข้า index

frames = [] #สร้างตัวเก็บข้อมูล

Index_province = Index(mohpromt2['จังหวัด']) #นำรายชื่อจังหวัดออกมา
Index_province = Index_province.drop('ไม่ทราบ') #เอาข้อมูลที่ไม่ปรากฏชื่อจังหวัดออก
Index_province = Index_province.drop_duplicates(keep='first') #โดยเก็บชื่อจังหวัดที่พบเป็นอันดับแรกไว้ที่ตัวแปร index_province

for i in nums(0, 76): #สร้างลูปให้ i เป็นเลขตั้งแต่ 0-76 คือแต่ละจังหวัดที่ 0-76 ของตาราง
  mp_province = mohpromt2[mohpromt2['จังหวัด'] == Index_province[i]] # ให้ mp_province คือ ตัวแปรที่แยกข้อมูล77จังหวัด
  mp_province = mp_province.head(1) # แยก mp_province ให้เหลือ 5 ข้อมูลแรกของแต่ละจังหวัด
  frames.append(mp_province) #นำข้อมูล 1 ข้อมูลของแต่ละจังหวัดเข้าไปไว้ใน frame

mohpromt_updated = pd.concat(frames) # รวมข้อมูล
mohpromt_updated # แสดงผล
# Out:
#                              ชื่อ  ประเภท       ตำบล               อำเภอ  \
# 0                     ร้านยาฟารุก  ร้านยา       แว้ง                แว้ง
# 1     อัสลามการแพทย์คลินิกเวชกรรม  คลินิก     บางอ้อ          เขตบางพลัด
# 2          ศูนย์ยาสี่แยกข่วงสิงห์  ร้านยา  ช้างเผือก      เมืองเชียงใหม่
# 3                      เอสทีเภสัช  ร้านยา    ในเมือง  เมืองนครศรีธรรมราช
# 4                      ร้านบู๊ทส์  ร้านยา   เชิงทะเล                ถลาง
# ...                           ...     ...        ...                 ...
# 1043                   ชัยยงเภสัช  ร้านยา  กาฬสินธุ์      เมืองกาฬสินธุ์
# 1185                เพรียว (Pure)  ร้านยา  หญ้าปล้อง       เมืองศรีสะเกษ
# 1518                แก้วอารีเภสัช  ร้านยา     บ้านนา              บ้านนา
# 1618                โพธิ์ทองโอสถ2  ร้านยา    เนินขาม             เนินขาม
# 2513               วัตสันฟาร์มาซี  ร้านยา     บางมัญ      เมืองสิงห์บุรี
#
#             จังหวัด
# 0          นราธิวาส
# 1     กรุงเทพมหานคร
# 2         เชียงใหม่
# 3     นครศรีธรรมราช
# 4            ภูเก็ต
# ...             ...
# 1043      กาฬสินธุ์
# 1185       ศรีสะเกษ
# 1518        นครนายก
# 1618         ชัยนาท
# 2513      สิงห์บุรี
#
# [77 rows x 5 columns]

# %% [markdown]
# # **ต่อตาราง data covid, data region และ data mohpromt

# %%
covid_region_mohpromt = covid_region_updated.merge(mohpromt_updated,how='left',left_on = 'จังหวัด',right_on = 'จังหวัด') 
#เชื่อมตาราง 2 ตาราง คือ covid_region_updated และ mohpromt_updated

covid_region_mohpromt #แสดงตาราง
# Out:
#              No. announce_date   sex   age  \
# 0              1    2020-01-12  หญิง  61.0
# 1              2    2020-01-17  หญิง  74.0
# 2              3    2020-01-22  หญิง  73.0
# 3              4    2020-01-22   ชาย  68.0
# 4              5    2020-01-24  หญิง  66.0
# ...          ...           ...   ...   ...
# 3005746  3423909    2022-03-23   ชาย  59.0
# 3005747  3423910    2022-03-23   ชาย  42.0
# 3005748  3423911    2022-03-23   ชาย  60.0
# 3005749  3423912    2022-03-23  หญิง  21.0
# 3005750  3423913    2022-03-23   ชาย  39.0
#
#                                             risk province_of_onset  \
# 0               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2               คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                          ...               ...
# 3005746  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3005747  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3005748  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3005749  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3005750  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
#
#                จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)                         ชื่อ  \
# 0        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 1        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 2               นครปฐม                   กลาง                   ร้านบู๊ทส์
# 3        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 4        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# ...                ...                    ...                          ...
# 3005746  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3005747  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3005748  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3005749  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3005750  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
#
#          ประเภท       ตำบล        อำเภอ
# 0        คลินิก     บางอ้อ   เขตบางพลัด
# 1        คลินิก     บางอ้อ   เขตบางพลัด
# 2        ร้านยา  ห้วยจรเข้  เมืองนครปฐม
# 3        คลินิก     บางอ้อ   เขตบางพลัด
# 4        คลินิก     บางอ้อ   เขตบางพลัด
# ...         ...        ...          ...
# 3005746  คลินิก     บางอ้อ   เขตบางพลัด
# 3005747  คลินิก     บางอ้อ   เขตบางพลัด
# 3005748  คลินิก     บางอ้อ   เขตบางพลัด
# 3005749  คลินิก     บางอ้อ   เขตบางพลัด
# 3005750  คลินิก     บางอ้อ   เขตบางพลัด
#
# [3005751 rows x 12 columns]

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
covid_region_mohpromt.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง covid_region_mohpromt
#เนื่องจากไม่มีค่า True แสดงว่าไม่มีค่าที่เป็น Missing แล้ว
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# risk                      False
# province_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# ชื่อ                      False
# ประเภท                    False
# ตำบล                      False
# อำเภอ                     False
# dtype: bool

# %% [markdown]
# # *เพิ่ม Latitude (ละติจูด) , Longitude (ลองจิจูด) เพื่อทำ map

# %%
import pandas as pd  #ทำงานกับข้อมูลลักษณะตาราง
import os  #จัดการไฟล์และ path

# %%
from google.colab import drive  #เชื่อม google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/Map'   #pathจะชี้ไปยังโฟล์เดอร์
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
map = os.path.join(path,'location.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(map)
# Out:
# /content/drive/My Drive/Map/location.xlsx

# %%
data_map = pd.read_excel(map)  #กำหนดตัวแปร data_map 
data_map  #เรียกดูตารางของแผนที่
# Out:
#           จังหวัด   Latitude   Longitude
# 0        นราธิวาส   5.927200  101.884500
# 1   กรุงเทพมหานคร  13.786690  100.605080
# 2       เชียงใหม่  18.811341   98.984177
# 3   นครศรีธรรมราช   8.407393   99.976526
# 4          ภูเก็ต   8.021930   98.338430
# ..            ...        ...         ...
# 72      กาฬสินธุ์  16.442592  103.508135
# 73       ศรีสะเกษ  15.120344  104.306625
# 74        นครนายก  14.262194  101.069667
# 75         ชัยนาท  14.952358   99.939476
# 76      สิงห์บุรี  14.905320  100.408360
#
# [77 rows x 3 columns]

# %% [markdown]
# # **ต่อตาราง data covid,data region,data mohpromt

# %%
covid_region_mohpromt_map = covid_region_mohpromt.merge(data_map,how='left',left_on = 'จังหวัด',right_on = 'จังหวัด') 
#เชื่อมตาราง 2 ตาราง คือ covid_region_mohpromt และ data_map

covid_region_mohpromt_map #แสดงตาราง
# Out:
#              No. announce_date   sex   age  \
# 0              1    2020-01-12  หญิง  61.0
# 1              2    2020-01-17  หญิง  74.0
# 2              3    2020-01-22  หญิง  73.0
# 3              4    2020-01-22   ชาย  68.0
# 4              5    2020-01-24  หญิง  66.0
# ...          ...           ...   ...   ...
# 3011973  3423909    2022-03-23   ชาย  59.0
# 3011974  3423910    2022-03-23   ชาย  42.0
# 3011975  3423911    2022-03-23   ชาย  60.0
# 3011976  3423912    2022-03-23  หญิง  21.0
# 3011977  3423913    2022-03-23   ชาย  39.0
#
#                                             risk province_of_onset  \
# 0               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2               คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                          ...               ...
# 3011973  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011974  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011975  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011976  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011977  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
#
#                จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)                         ชื่อ  \
# 0        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 1        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 2               นครปฐม                   กลาง                   ร้านบู๊ทส์
# 3        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 4        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# ...                ...                    ...                          ...
# 3011973  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3011974  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3011975  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3011976  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3011977  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
#
#          ประเภท       ตำบล        อำเภอ  Latitude  Longitude
# 0        คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 1        คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 2        ร้านยา  ห้วยจรเข้  เมืองนครปฐม  13.81282  100.07484
# 3        คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 4        คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# ...         ...        ...          ...       ...        ...
# 3011973  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 3011974  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 3011975  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 3011976  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 3011977  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
#
# [3011978 rows x 14 columns]

# %% [markdown]
# #### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
data_dashboard = covid_region_mohpromt_map.dropna() #ตัดค่าว่างออก
data_dashboard
# Out:
#              No. announce_date   sex   age  \
# 0              1    2020-01-12  หญิง  61.0
# 1              2    2020-01-17  หญิง  74.0
# 2              3    2020-01-22  หญิง  73.0
# 3              4    2020-01-22   ชาย  68.0
# 4              5    2020-01-24  หญิง  66.0
# ...          ...           ...   ...   ...
# 3011973  3423909    2022-03-23   ชาย  59.0
# 3011974  3423910    2022-03-23   ชาย  42.0
# 3011975  3423911    2022-03-23   ชาย  60.0
# 3011976  3423912    2022-03-23  หญิง  21.0
# 3011977  3423913    2022-03-23   ชาย  39.0
#
#                                             risk province_of_onset  \
# 0               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2               คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                          ...               ...
# 3011973  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011974  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011975  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011976  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
# 3011977  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ     กรุงเทพมหานคร
#
#                จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)                         ชื่อ  \
# 0        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 1        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 2               นครปฐม                   กลาง                   ร้านบู๊ทส์
# 3        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 4        กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# ...                ...                    ...                          ...
# 3011973  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3011974  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3011975  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3011976  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3011977  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
#
#          ประเภท       ตำบล        อำเภอ  Latitude  Longitude
# 0        คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 1        คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 2        ร้านยา  ห้วยจรเข้  เมืองนครปฐม  13.81282  100.07484
# 3        คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 4        คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# ...         ...        ...          ...       ...        ...
# 3011973  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 3011974  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 3011975  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 3011976  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
# 3011977  คลินิก     บางอ้อ   เขตบางพลัด  13.78669  100.60508
#
# [3002377 rows x 14 columns]

# %%
data_dashboard.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง data_dashboard
#เนื่องจากไม่มีค่า True แสดงว่าไม่มีค่าที่เป็น Missing แล้ว
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# risk                      False
# province_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# ชื่อ                      False
# ประเภท                    False
# ตำบล                      False
# อำเภอ                     False
# Latitude                  False
# Longitude                 False
# dtype: bool

# %% [markdown]
# # ข้อมูลเฟส 1

# %%
Phase1 = data_dashboard[(data_dashboard['announce_date']>='2020-10-23') & (data_dashboard['announce_date']<='2020-12-31')]
Phase1
# Out:
#        No. announce_date   sex   age  \
# 3662  3721    2020-10-23  หญิง  31.0
# 3663  3722    2020-10-23   ชาย  32.0
# 3664  3723    2020-10-23   ชาย  54.0
# 3665  3724    2020-10-23   ชาย  20.0
# 3666  3725    2020-10-23  หญิง  40.0
# ...    ...           ...   ...   ...
# 6521  6880    2020-12-31   ชาย  42.0
# 6522  6881    2020-12-31  หญิง  39.0
# 6523  6883    2020-12-31   ชาย  54.0
# 6524  6884    2020-12-31   ชาย  56.0
# 6525  6885    2020-12-31   ชาย  70.0
#
#                                               risk province_of_onset  \
# 3662                              State Quarantine     กรุงเทพมหานคร
# 3663                              State Quarantine            ชลบุรี
# 3664  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ       สมุทรปราการ
# 3665  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ     กรุงเทพมหานคร
# 3666  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ     กรุงเทพมหานคร
# ...                                            ...               ...
# 6521                                 Cluster ระยอง             ระยอง
# 6522                                 Cluster ระยอง             ระยอง
# 6523                                 Cluster ระยอง             ระยอง
# 6524                                 Cluster ระยอง             ระยอง
# 6525                                 Cluster ระยอง             ระยอง
#
#             จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)                         ชื่อ  \
# 3662  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3663         ชลบุรี               ตะวันออก                  ร้าน บู๊ทส์
# 3664    สมุทรปราการ                   กลาง                  ร้าน บู๊ทส์
# 3665  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 3666  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# ...             ...                    ...                          ...
# 6521          ระยอง               ตะวันออก                       บู๊ทส์
# 6522          ระยอง               ตะวันออก                       บู๊ทส์
# 6523          ระยอง               ตะวันออก                       บู๊ทส์
# 6524          ระยอง               ตะวันออก                       บู๊ทส์
# 6525          ระยอง               ตะวันออก                       บู๊ทส์
#
#       ประเภท      ตำบล       อำเภอ   Latitude   Longitude
# 3662  คลินิก    บางอ้อ  เขตบางพลัด  13.786690  100.605080
# 3663  ร้านยา   ศรีราชา     ศรีราชา  13.168710  100.932250
# 3664  ร้านยา   บางแก้ว      บางพลี  13.646786  100.680613
# 3665  คลินิก    บางอ้อ  เขตบางพลัด  13.786690  100.605080
# 3666  คลินิก    บางอ้อ  เขตบางพลัด  13.786690  100.605080
# ...      ...       ...         ...        ...         ...
# 6521  ร้านยา  เชิงเนิน  เมืองระยอง  12.696543  101.269252
# 6522  ร้านยา  เชิงเนิน  เมืองระยอง  12.696543  101.269252
# 6523  ร้านยา  เชิงเนิน  เมืองระยอง  12.696543  101.269252
# 6524  ร้านยา  เชิงเนิน  เมืองระยอง  12.696543  101.269252
# 6525  ร้านยา  เชิงเนิน  เมืองระยอง  12.696543  101.269252
#
# [2861 rows x 14 columns]

# %% [markdown]
# # ข้อมูลเฟส 2

# %%
Phase2 = data_dashboard[(data_dashboard['announce_date']>='2021-01-01') & (data_dashboard['announce_date']<='2021-03-31')]
Phase2
# Out:
#          No. announce_date   sex   age                              risk  \
# 124      125    2021-03-06  หญิง  55.0               Cluster ตลาดพรพัฒน์
# 6526    6886    2021-01-01  หญิง  40.0                 Cluster สมุทรสาคร
# 6527    6887    2021-01-01  หญิง  21.0                     Cluster ระยอง
# 6528    6888    2021-01-01  หญิง  20.0                       สถานบันเทิง
# 6529    6889    2021-01-01  หญิง  47.0                 Cluster สมุทรสาคร
# ...      ...           ...   ...   ...                               ...
# 26314  28859    2021-03-31   ชาย  35.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 26315  28860    2021-03-31   ชาย  63.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 26316  28861    2021-03-31  หญิง  34.0                  State Quarantine
# 26317  28862    2021-03-31  หญิง  22.0                  State Quarantine
# 26318  28863    2021-03-31   ชาย  17.0                  State Quarantine
#
#       province_of_onset        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)  \
# 124            ปทุมธานี       ปทุมธานี                   กลาง
# 6526           ปทุมธานี       ปทุมธานี                   กลาง
# 6527           ปทุมธานี       ปทุมธานี                   กลาง
# 6528             นครปฐม         นครปฐม                   กลาง
# 6529             นครปฐม         นครปฐม                   กลาง
# ...                 ...            ...                    ...
# 26314     กรุงเทพมหานคร  กรุงเทพมหานคร                   กลาง
# 26315     กรุงเทพมหานคร  กรุงเทพมหานคร                   กลาง
# 26316           สระแก้ว        สระแก้ว               ตะวันออก
# 26317               ตาก            ตาก                ตะวันตก
# 26318          นราธิวาส       นราธิวาส                    ใต้
#
#                               ชื่อ  ประเภท        ตำบล         อำเภอ  \
# 124                     ร้านบู๊ทส์  ร้านยา  บึงคำพร้อย       ลำลูกกา
# 6526                    ร้านบู๊ทส์  ร้านยา  บึงคำพร้อย       ลำลูกกา
# 6527                    ร้านบู๊ทส์  ร้านยา  บึงคำพร้อย       ลำลูกกา
# 6528                    ร้านบู๊ทส์  ร้านยา   ห้วยจรเข้   เมืองนครปฐม
# 6529                    ร้านบู๊ทส์  ร้านยา   ห้วยจรเข้   เมืองนครปฐม
# ...                            ...     ...         ...           ...
# 26314  อัสลามการแพทย์คลินิกเวชกรรม  คลินิก      บางอ้อ    เขตบางพลัด
# 26315  อัสลามการแพทย์คลินิกเวชกรรม  คลินิก      บางอ้อ    เขตบางพลัด
# 26316                 วาวาฟาร์มาซี  ร้านยา     สระแก้ว  เมืองสระแก้ว
# 26317                  ร้าน บู๊ทส์  ร้านยา      แม่สอด        แม่สอด
# 26318                  ร้านยาฟารุก  ร้านยา        แว้ง          แว้ง
#
#         Latitude   Longitude
# 124    13.935973  100.737487
# 6526   13.935973  100.737487
# 6527   13.935973  100.737487
# 6528   13.812820  100.074840
# 6529   13.812820  100.074840
# ...          ...         ...
# 26314  13.786690  100.605080
# 26315  13.786690  100.605080
# 26316  13.832688  102.063773
# 26317  16.723330   98.588230
# 26318   5.927200  101.884500
#
# [19793 rows x 14 columns]

# %% [markdown]
# # ข้อมูลเฟส 3

# %%
Phase3 = data_dashboard[(data_dashboard['announce_date']>='2021-10-01') & (data_dashboard['announce_date']<='2021-10-16')]
Phase3
# Out:
#              No. announce_date   sex      age  \
# 1390219  1603476    2021-10-01  หญิง     30.0
# 1390220  1603476    2021-10-01  หญิง     30.0
# 1390221  1603477    2021-10-01  หญิง     32.0
# 1390222  1603477    2021-10-01  หญิง     32.0
# 1390223  1603478    2021-10-01  หญิง     38.0
# ...          ...           ...   ...      ...
# 1538037  1772834    2021-10-16   ชาย  ไม่ทราบ
# 1538038  1772835    2021-10-16   ชาย  ไม่ทราบ
# 1538039  1772836    2021-10-16   ชาย  ไม่ทราบ
# 1538040  1772837    2021-10-16   ชาย  ไม่ทราบ
# 1538041  1772838    2021-10-16   ชาย  ไม่ทราบ
#
#                                                 risk province_of_onset  \
# 1390219                                        อื่นๆ             พะเยา
# 1390220                                        อื่นๆ             พะเยา
# 1390221                                        อื่นๆ             พะเยา
# 1390222                                        อื่นๆ             พะเยา
# 1390223  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          เชียงราย
# ...                                              ...               ...
# 1538037                             ทัณฑสถาน/เรือนจำ           ขอนแก่น
# 1538038                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 1538039                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 1538040                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 1538041                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
#
#                จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)                         ชื่อ  \
# 1390219          พะเยา                  เหนือ                  ยาพัชรินทร์
# 1390220          พะเยา                  เหนือ                  ยาพัชรินทร์
# 1390221          พะเยา                  เหนือ                  ยาพัชรินทร์
# 1390222          พะเยา                  เหนือ                  ยาพัชรินทร์
# 1390223       เชียงราย                  เหนือ                       บู๊ทส์
# ...                ...                    ...                          ...
# 1538037        ขอนแก่น     ตะวันออกเฉียงเหนือ                   ต้นยาเภสัช
# 1538038  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 1538039  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 1538040  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 1538041  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
#
#          ประเภท      ตำบล          อำเภอ   Latitude   Longitude
# 1390219  ร้านยา     หย่วน        เชียงคำ  19.526198  100.302483
# 1390220  ร้านยา     หย่วน        เชียงคำ  19.029781   99.926232
# 1390221  ร้านยา     หย่วน        เชียงคำ  19.526198  100.302483
# 1390222  ร้านยา     หย่วน        เชียงคำ  19.029781   99.926232
# 1390223  ร้านยา     เวียง  เมืองเชียงราย  19.905460   99.834120
# ...         ...       ...            ...        ...         ...
# 1538037  ร้านยา  บ้านเป็ด   เมืองขอนแก่น  16.457131  102.795328
# 1538038  คลินิก    บางอ้อ     เขตบางพลัด  13.786690  100.605080
# 1538039  คลินิก    บางอ้อ     เขตบางพลัด  13.786690  100.605080
# 1538040  คลินิก    บางอ้อ     เขตบางพลัด  13.786690  100.605080
# 1538041  คลินิก    บางอ้อ     เขตบางพลัด  13.786690  100.605080
#
# [147621 rows x 14 columns]

# %% [markdown]
# # ข้อมูลเฟส 4

# %%
Phase4 = data_dashboard[(data_dashboard['announce_date']>='2022-02-01') & (data_dashboard['announce_date']<='2022-02-16')]
Phase4
# Out:
#              No. announce_date   sex      age  \
# 2139214  2440543    2022-02-01  หญิง       35
# 2139215  2440543    2022-02-01  หญิง       35
# 2139216  2440544    2022-02-01  หญิง       19
# 2139217  2440544    2022-02-01  หญิง       19
# 2139218  2440545    2022-02-01  หญิง        8
# ...          ...           ...   ...      ...
# 2317577  2639058    2022-02-16   ชาย  ไม่ทราบ
# 2317578  2639059    2022-02-16   ชาย  ไม่ทราบ
# 2317579  2639060    2022-02-16   ชาย  ไม่ทราบ
# 2317580  2639061    2022-02-16   ชาย  ไม่ทราบ
# 2317581  2639062    2022-02-16   ชาย  ไม่ทราบ
#
#                                                 risk province_of_onset  \
# 2139214                                        อื่นๆ             พะเยา
# 2139215                                        อื่นๆ             พะเยา
# 2139216  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2139217  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2139218  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...                                              ...               ...
# 2317577                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 2317578                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 2317579                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 2317580                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
# 2317581                             ทัณฑสถาน/เรือนจำ     กรุงเทพมหานคร
#
#                จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)                         ชื่อ  \
# 2139214          พะเยา                  เหนือ                  ยาพัชรินทร์
# 2139215          พะเยา                  เหนือ                  ยาพัชรินทร์
# 2139216          พะเยา                  เหนือ                  ยาพัชรินทร์
# 2139217          พะเยา                  เหนือ                  ยาพัชรินทร์
# 2139218          พะเยา                  เหนือ                  ยาพัชรินทร์
# ...                ...                    ...                          ...
# 2317577  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 2317578  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 2317579  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 2317580  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
# 2317581  กรุงเทพมหานคร                   กลาง  อัสลามการแพทย์คลินิกเวชกรรม
#
#          ประเภท    ตำบล       อำเภอ   Latitude   Longitude
# 2139214  ร้านยา   หย่วน     เชียงคำ  19.526198  100.302483
# 2139215  ร้านยา   หย่วน     เชียงคำ  19.029781   99.926232
# 2139216  ร้านยา   หย่วน     เชียงคำ  19.526198  100.302483
# 2139217  ร้านยา   หย่วน     เชียงคำ  19.029781   99.926232
# 2139218  ร้านยา   หย่วน     เชียงคำ  19.526198  100.302483
# ...         ...     ...         ...        ...         ...
# 2317577  คลินิก  บางอ้อ  เขตบางพลัด  13.786690  100.605080
# 2317578  คลินิก  บางอ้อ  เขตบางพลัด  13.786690  100.605080
# 2317579  คลินิก  บางอ้อ  เขตบางพลัด  13.786690  100.605080
# 2317580  คลินิก  บางอ้อ  เขตบางพลัด  13.786690  100.605080
# 2317581  คลินิก  บางอ้อ  เขตบางพลัด  13.786690  100.605080
#
# [177361 rows x 14 columns]

# %% [markdown]
# # save file เพื่อทำ Dashboad

# %%
Phase1.to_csv('dashboad1.csv', encoding='utf-8')

# %%
Phase2.to_csv('dashboad2.csv', encoding='utf-8')

# %%
Phase3.to_csv('dashboad3.csv', encoding='utf-8')

# %%
Phase4.to_csv('dashboad4.csv', encoding='utf-8')

# %% [markdown]
# # ลิงค์ Dashboard
# https://datastudio.google.com/reporting/ea6e46c9-1e34-4d70-98eb-91021087a551
